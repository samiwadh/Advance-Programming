# %% [markdown]
# # Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # import dataset of placement

# %%
place_df = pd.read_csv('placement.csv')
place_df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
place_df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
place_df.tail()
# Out:
#      cgpa  package
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33

# %%
place_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
# Analyze data
 
place_df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
# Distribution
plt.title('Placement  Plot')
sns.distplot(place_df['package'])
plt.show()
# Out:
# C:\Users\samiwadho\AppData\Local\Temp\ipykernel_19172\3747532350.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(place_df['package'])
# D:\Software\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Line chart

# %%
plt.plot(place_df['cgpa'],place_df['package'],marker = 'o',markeredgecolor ='black',color ='green',linestyle='solid',label = 'placement')
plt.xlabel('cgpa')
plt.ylabel('package')
plt.title('placement of grade ')

plt.legend()
plt.show()

# %%
plt.scatter(place_df['cgpa'],place_df['package'],color = 'brown',label = 'Placement')

plt.xlabel('cgpa')
plt.ylabel('package')
plt.title('placement of grade ')
plt.legend()

plt.show()

# %%
# Splitting variables
X = place_df.iloc[:, :1]  #as we know y axis is independent
y = place_df.iloc[:, 1:]  #as we know x axis is  dependent

# %%
from sklearn.model_selection import train_test_split

# using the sklearn train and test funtion 

X_train , X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3 , random_state =  0)
X_train , X_test, y_train, y_test
# Out:
# (     cgpa
#  131  6.37
#  96   7.11
#  181  8.22
#  19   7.48
#  153  7.94
#  ..    ...
#  67   6.51
#  192  8.25
#  117  7.12
#  47   5.84
#  172  6.93
#
#  [140 rows x 1 columns],
#       cgpa
#  18   6.94
#  170  6.22
#  107  6.33
#  98   7.69
#  177  7.09
#  182  5.88
#  5    7.89
#  146  6.07
#  12   8.94
#  152  7.37
#  61   5.48
#  125  7.33
#  180  6.19
#  154  7.08
#  80   7.63
#  7    6.75
#  33   6.35
#  130  6.68
#  37   5.90
#  74   6.85
#  183  7.28
#  145  5.84
#  45   7.87
#  159  8.71
#  60   5.61
#  123  5.10
#  179  7.14
#  185  6.31
#  122  5.12
#  44   5.09
#  16   6.84
#  55   8.20
#  150  6.30
#  111  5.42
#  22   6.14
#  189  8.11
#  129  7.29
#  4    6.94
#  83   8.44
#  106  6.13
#  134  7.20
#  66   5.11
#  26   8.31
#  113  6.94
#  168  8.65
#  63   9.16
#  8    6.09
#  75   6.97
#  118  7.40
#  143  4.85
#  71   7.47
#  124  6.06
#  184  7.88
#  97   5.98
#  149  8.28
#  24   6.53
#  30   7.36
#  160  7.13
#  40   9.38
#  56   5.84,
#       package
# ...

# %%
# Regressor model import linear regression liberry 
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # or in other way we can use leaner regression model

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)
reg
# Out:
# LinearRegression()

# %%
# now we are going to Predict Results
y_pred_train = reg.predict(X_train)
y_pred_test  =reg.predict(X_test)

# %% [markdown]
# # now we are going the show or visuial the train model of linear regression

# %%
plt.scatter(X_train,y_train,label = 'predict data')
plt.plot(X_train,y_train, color = 'brown',label = 'original data')
plt.title('Placement')
plt.xlabel('package')
plt.ylabel('cgpa')
plt.legend()

plt.show()

# %%
plt.scatter(X_train,y_train,label = 'predict data')
plt.plot(X_train,y_train, color = 'brown',label = 'original data')
plt.title('Placement')
plt.xlabel('package')
plt.ylabel('cgpa')
plt.legend()

plt.box(False)
# Prediction on test set

plt.show()

# %%
# Regressor coefficients and intercept
print(f'Coefficient: {reg.coef_}')
print(f'Intercept: {reg.intercept_}')
print('y = ', reg.intercept_, '+', reg.coef_, '* X')
# Out:
# Coefficient: [[0.58948085]]
# Intercept: [-1.10357822]
# y =  [-1.10357822] + [[0.58948085]] * X

# %%
# evaluate the model
print('MSE = ', mean_squared_error(y_test, y_pred_test ))
print('R2 = ', r2_score(y_test, y_pred_test ))
print('RMSE = ', np.sqrt(mean_squared_error(y_test, y_pred_test )))
# Out:
# MSE =  0.10197736592874906
# R2 =  0.7509091646328011
# RMSE =  0.31933895147436847
