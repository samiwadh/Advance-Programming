# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
insur_data = pd.read_csv('insurance_data.csv')
insur_data.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(insur_data['age'],insur_data['bought_insurance'],marker = 'o',color = 'brown')

# %%
plt.plot(insur_data['age'],insur_data['bought_insurance'] , marker = 'o', markeredgecolor = 'Black')

X = insur_data.iloc[:, :1]
Y = insur_data.iloc[:, 1:]

# %%
X_train , X_test ,Y_train , Y_test = train_test_split((X,Y, train_size=0.8))
# Out:
#   File "<ipython-input-19-2c8b481859d7>", line 1
#     X_train , X_test ,Y_train , Y_test = train_test_split((X,Y, train_size=0.8))
#                                                                 ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
