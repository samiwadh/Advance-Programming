# %%
import numpy as np
import pandas as pd

# %%
cus =pd.read_csv('Churn.csv')
cus.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
cus.shape
# Out:
# (10000, 14)

# %%
cus.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
cus.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#spliting
x = cus.iloc[:, :1]
y = cus.iloc[:, 1:]

# %%
from sklearn.model_selection import train_test_split


X_train , X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3 , random_state =  0)
X_train , X_test, y_train, y_test
# Out:
# (      RowNumber
#  7681       7682
#  9031       9032
#  3691       3692
#  202         203
#  5625       5626
#  ...         ...
#  9225       9226
#  4859       4860
#  3264       3265
#  9845       9846
#  2732       2733
#
#  [7000 rows x 1 columns],
#        RowNumber
#  9394       9395
#  898         899
#  2398       2399
#  5906       5907
#  2343       2344
#  ...         ...
#  4004       4005
#  7375       7376
#  9307       9308
#  8394       8395
#  5233       5234
#
#  [3000 rows x 1 columns],
#        CustomerId           Surname  CreditScore Geography  Gender  Age  \
#  7681    15633608             Black          641    France    Male   33
#  9031    15742323            Barese          541    France    Male   39
#  3691    15760244              Ives          590    France  Female   76
#  202     15600974                He          516     Spain    Male   50
#  5625    15663234            Bishop          508    France  Female   60
# ...

# %%
cus.isnull().sum() # for finding those data where is no data filled and .sum mean tell me how much null data in those colums
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
import skimpy as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5484/3086945224.py in <module>
# ----> 1 import skimpy as sk
#
# ModuleNotFoundError: No module named 'skimpy'

# %%
sk.skim(cus) # for urgent we generate this file it show numerical and catagrical
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5484/3864873695.py in <module>
# ----> 1 sk.skim(cus) # for urgent we generate this file it show numerical and catagrical
#
# NameError: name 'sk' is not defined

# %%
cus = pd.get_dummies(cus,columns=['Geography','Gender'],drop_first=True)

# %%
cus.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geography_Germany  Geography_Spain  Gender_Male
# 0                  0                0            0
# ...

# %%
x = cus.drop(columns=['Exited'])
y = cus['Exited'].values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#       RowNumber  CustomerId           Surname  CreditScore  Age  Tenure  \
# 7389       7390    15676909            Mishin          667   34       5
# 9275       9276    15749265           Carslaw          427   42       1
# 2995       2996    15582492             Moore          535   29       2
# 5316       5317    15780386             Ferri          654   40       5
# 356         357    15611759           Simmons          850   57       8
# ...         ...         ...               ...          ...  ...     ...
# 9225       9226    15584928  Ugochukwutubelum          594   32       4
# 4859       4860    15647111             White          794   22       4
# 3264       3265    15574372            Hoolan          738   35       5
# 9845       9846    15664035           Parsons          590   38       9
# 2732       2733    15592816          Udokamma          623   48       1
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5484/128434654.py in <module>
# ----> 1 import tensorflow
#       2 from tensorflow import keras
#       3 from tensorflow.keras import Sequential
#       4 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.16.1-cp39-cp39-win_amd64.whl (2.1 kB)
# ...
#   Using cached tensorflow_intel-2.16.1-cp39-cp39-win_amd64.whl (376.9 MB)
# ...
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached ml_dtypes-0.3.2-cp39-cp39-win_amd64.whl (127 kB)
# ...
#   Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# ...
#   Using cached keras-3.3.3-py3-none-any.whl (1.1 MB)
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\__pycache__\\typing_extensions.cpython-39.pyc'
#   Using cached grpcio-1.64.0-cp39-cp39-win_amd64.whl (4.1 MB)
# ...
#   Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl (3.0 MB)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# ...

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5484/128434654.py in <module>
# ----> 1 import tensorflow
#       2 from tensorflow import keras
#       3 from tensorflow.keras import Sequential
#       4 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5484/3881451461.py in <module>
#       2 scaler = StandardScaler()
#       3
# ----> 4 X_train_scaled = scaler.fit_transform(X_train)
#       5 X_test_scaled = scaler.transform(X_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# ...
