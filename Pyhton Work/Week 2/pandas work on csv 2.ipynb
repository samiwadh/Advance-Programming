# %%
import pandas as pd 
ipl = pd.read_csv('ipl.csv')

# %%
ipl
# Out:
#      ﻿id  season           city        date                        team1  \
# 0      1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 1      2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# 2      3    2008          Delhi  2008-04-19             Rajasthan Royals
# 3      4    2008         Mumbai  2008-04-20               Mumbai Indians
# 4      5    2008        Kolkata  2008-04-20              Deccan Chargers
# 5      6    2008         Jaipur  2008-04-21              Kings XI Punjab
# 6      7    2008      Hyderabad  2008-04-22              Deccan Chargers
# 7      8    2008        Chennai  2008-04-23          Chennai Super Kings
# 8      9    2008      Hyderabad  2008-04-24              Deccan Chargers
# 9     10    2008     Chandigarh  2008-04-25              Kings XI Punjab
# 10    11    2008      Bangalore  2008-04-26  Royal Challengers Bangalore
# 11    12    2008        Chennai  2008-04-26        Kolkata Knight Riders
# ...

# %%
my_series = ipl["winner"].value_counts()
my_series
# Out:
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
my_series.index[4]  #finding indexing  = loc
# Out:
# 'Rajasthan Royals'

# %%
my_series.loc

# %%
my_series[4] # finding value or iloc
# Out:
# 63

# %%
# finding 
my_series[0]
# Out:
# 80

# %%
ipl['team1'].value_counts()
# Out:
# Chennai Super Kings            77
# Mumbai Indians                 76
# Kings XI Punjab                69
# Royal Challengers Bangalore    62
# Kolkata Knight Riders          62
# Delhi Daredevils               57
# Rajasthan Royals               54
# Deccan Chargers                43
# Sunrisers Hyderabad            37
# Pune Warriors                  20
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            7
# Gujarat Lions                   6
# Name: team1, dtype: int64

# %%
# total mat
ipl['team1'].value_counts()+ipl['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               133
# Gujarat Lions                   16
# Kings XI Punjab                134
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          132
# Mumbai Indians                 140
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    139
# Sunrisers Hyderabad             62
# dtype: int64

# %%
ipl['team1'].value_counts()+ipl['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               133
# Gujarat Lions                   16
# Kings XI Punjab                134
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          132
# Mumbai Indians                 140
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    139
# Sunrisers Hyderabad             62
# dtype: int64

# %%
both_team =ipl['team1'].value_counts()+ipl['team2'].value_counts()
both_team
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               133
# Gujarat Lions                   16
# Kings XI Punjab                134
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          132
# Mumbai Indians                 140
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    139
# Sunrisers Hyderabad             62
# dtype: int64

# %%
both_team.sort_values(ascending = False)
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# Chennai Super Kings            131
# Rajasthan Royals               118
# Deccan Chargers                 75
# Sunrisers Hyderabad             62
# Pune Warriors                   46
# Gujarat Lions                   16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
#finding top 5 team
both_team.sort_values(ascending = False).head()
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# dtype: int64

# %%
both_team.tail(ascending)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e2ed4b38674b> in <module>()
# ----> 1 both_team.tail(ascending)
#
# NameError: name 'ascending' is not defined

# %%
ipl.sort_values('date')
# Out:
#      ﻿id  season           city        date                        team1  \
# 0      1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 1      2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# 2      3    2008          Delhi  2008-04-19             Rajasthan Royals
# 3      4    2008         Mumbai  2008-04-20               Mumbai Indians
# 4      5    2008        Kolkata  2008-04-20              Deccan Chargers
# 5      6    2008         Jaipur  2008-04-21              Kings XI Punjab
# 6      7    2008      Hyderabad  2008-04-22              Deccan Chargers
# 7      8    2008        Chennai  2008-04-23          Chennai Super Kings
# 8      9    2008      Hyderabad  2008-04-24              Deccan Chargers
# 9     10    2008     Chandigarh  2008-04-25              Kings XI Punjab
# 10    11    2008      Bangalore  2008-04-26  Royal Challengers Bangalore
# 11    12    2008        Chennai  2008-04-26        Kolkata Knight Riders
# ...

# %%
ipl.sort_values(['city','date'],ascending = [False, True])
# Out:
#      ﻿id  season           city        date                        team1  \
# 253  254    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 256  257    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 469  470    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 471  472    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 477  478    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 553  554    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 556  557    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 559  560    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 563  564    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 565  566    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 569  570    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 399  400    2014        Sharjah  2014-04-17             Delhi Daredevils
# ...

# %%
ipl.sort_values(['city','date'],ascending = [True,False])
# Out:
#      ﻿id  season           city        date                        team1  \
# 416  417    2014      Abu Dhabi  2014-04-29             Rajasthan Royals
# 411  412    2014      Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 412  413    2014      Abu Dhabi  2014-04-26              Kings XI Punjab
# 405  406    2014      Abu Dhabi  2014-04-21          Chennai Super Kings
# 400  401    2014      Abu Dhabi  2014-04-18          Chennai Super Kings
# 401  402    2014      Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 398  399    2014      Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 480  481    2015      Ahmedabad  2015-04-24             Rajasthan Royals
# 476  477    2015      Ahmedabad  2015-04-21             Rajasthan Royals
# 473  474    2015      Ahmedabad  2015-04-19          Chennai Super Kings
# 466  467    2015      Ahmedabad  2015-04-14               Mumbai Indians
# 441  442    2014      Ahmedabad  2014-05-19               Mumbai Indians
# ...

# %%
ipl.shape
# Out:
# (577, 18)

# %%
ipl.drop_duplicates('season')
# Out:
#      ﻿id  season       city        date                  team1  \
# 0      1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
# 58    59    2009  Cape Town  2009-04-18         Mumbai Indians
# 115  116    2010     Mumbai  2010-03-12  Kolkata Knight Riders
# 175  176    2011    Chennai  2011-04-08    Chennai Super Kings
# 248  249    2012    Chennai  2012-04-04    Chennai Super Kings
# 322  323    2013    Kolkata  2013-04-03       Delhi Daredevils
# 398  399    2014  Abu Dhabi  2014-04-16  Kolkata Knight Riders
# 458  459    2015    Kolkata  2015-04-08         Mumbai Indians
# 517  518    2016     Mumbai  2016-04-09         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 58           Chennai Super Kings          Chennai Super Kings         field
# 115              Deccan Chargers              Deccan Chargers         field
# ...

# %%
ipl.drop_duplicates('season', keep = 'last')[['season','winner']] # keep last me there are 8
# Out:
#      season                 winner
# 57     2008       Rajasthan Royals
# 114    2009        Deccan Chargers
# 174    2010    Chennai Super Kings
# 247    2011    Chennai Super Kings
# 321    2012  Kolkata Knight Riders
# 397    2013         Mumbai Indians
# 457    2014  Kolkata Knight Riders
# 516    2015         Mumbai Indians
# 576    2016    Sunrisers Hyderabad

# %%
ipl
